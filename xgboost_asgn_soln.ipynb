# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics    
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
train_set = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', sep=' *, *',header = None,na_values="?")
# Out:
# C:\Users\rt\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
test_set = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test' , sep=' *, *',skiprows = 1, header = None,na_values= "?")
# Out:
# C:\Users\rt\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
train_set.shape
# Out:
# (32561, 15)

# %%
test_set.shape
# Out:
# (16281, 15)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32561 non-null  int64
#  1   1       30725 non-null  object
#  2   2       32561 non-null  int64
#  3   3       32561 non-null  object
#  4   4       32561 non-null  int64
#  5   5       32561 non-null  object
#  6   6       30718 non-null  object
#  7   7       32561 non-null  object
#  8   8       32561 non-null  object
#  9   9       32561 non-null  object
#  10  10      32561 non-null  int64
#  11  11      32561 non-null  int64
#  12  12      32561 non-null  int64
#  13  13      31978 non-null  object
#  14  14      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
train_set.isnull().sum()
# Out:
# 0        0
# 1     1836
# 2        0
# 3        0
# 4        0
# 5        0
# 6     1843
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       0
# 13     583
# 14       0
# dtype: int64

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       16281 non-null  int64
#  1   1       15318 non-null  object
#  2   2       16281 non-null  int64
#  3   3       16281 non-null  object
#  4   4       16281 non-null  int64
#  5   5       16281 non-null  object
#  6   6       15315 non-null  object
#  7   7       16281 non-null  object
#  8   8       16281 non-null  object
#  9   9       16281 non-null  object
#  10  10      16281 non-null  int64
#  11  11      16281 non-null  int64
#  12  12      16281 non-null  int64
#  13  13      16007 non-null  object
#  14  14      16281 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.9+ MB

# %%
test_set.isnull().sum()
# Out:
# 0       0
# 1     963
# 2       0
# 3       0
# 4       0
# 5       0
# 6     966
# 7       0
# 8       0
# 9       0
# 10      0
# 11      0
# 12      0
# 13    274
# 14      0
# dtype: int64

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
'marital_status', 'occupation','relationship', 'race', 'sex', 'capital_gain',
'capital_loss', 'hours_per_week', 'native_country', 'wage_class']

# %%
train_set.columns = col_labels
test_set.columns = col_labels

# %%
adult=pd.concat([train_set,test_set])

# %%
adult
# Out:
#        age         workclass  fnlwgt  education  education_num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 16276   39           Private  215419  Bachelors             13
# 16277   64               NaN  321403    HS-grad              9
# 16278   38           Private  374983  Bachelors             13
# 16279   44           Private   83891  Bachelors             13
# 16280   35      Self-emp-inc  182148  Bachelors             13
#
#            marital_status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 16276            Divorced     Prof-specialty   Not-in-family
# 16277             Widowed                NaN  Other-relative
# 16278  Married-civ-spouse     Prof-specialty         Husband
# 16279            Divorced       Adm-clerical       Own-child
# 16280  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 16276               White  Female             0             0              36
# 16277               Black    Male             0             0              40
# 16278               White    Male             0             0              50
# 16279  Asian-Pac-Islander    Male          5455             0              40
# 16280               White    Male             0             0              60
#
#       native_country wage_class
# 0      United-States      <=50K
# 1      United-States      <=50K
# 2      United-States      <=50K
# 3      United-States      <=50K
# 4               Cuba      <=50K
# ...              ...        ...
# 16276  United-States     <=50K.
# 16277  United-States     <=50K.
# 16278  United-States     <=50K.
# 16279  United-States     <=50K.
# 16280  United-States      >50K.
#
# [48842 rows x 15 columns]

# %%
adult['wage_class'] = adult['wage_class'].replace('<=50K', 0).replace('>50K', 1)
adult['wage_class'] =adult['wage_class'].replace('<=50K.', 0).replace('>50K.', 1)

# %%
ad_target=adult['wage_class']

# %%
ad_target
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16276    0
# 16277    0
# 16278    0
# 16279    0
# 16280    1
# Name: wage_class, Length: 48842, dtype: int64

# %%
adult=adult.drop(['wage_class'],axis=1)

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48842 entries, 0 to 16280
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education_num   48842 non-null  int64
#  5   marital_status  48842 non-null  object
#  6   occupation      46033 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital_gain    48842 non-null  int64
#  11  capital_loss    48842 non-null  int64
#  12  hours_per_week  48842 non-null  int64
#  13  native_country  47985 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 5.6+ MB

# %%
adult.isnull().sum()
# Out:
# age                  0
# workclass         2799
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     857
# dtype: int64

# %%
adult.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   48842.000000     46043  4.884200e+04     48842   48842.000000
# unique           NaN         8           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     33906           NaN     15784            NaN
# mean       38.643585       NaN  1.896641e+05       NaN      10.078089
# std        13.710510       NaN  1.056040e+05       NaN       2.570973
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN       9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN      10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN      12.000000
# max        90.000000       NaN  1.490400e+06       NaN      16.000000
#
#             marital_status      occupation relationship   race    sex  \
# count                48842           46033        48842  48842  48842
# unique                   7              14            6      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 22379            6172        19716  41762  32650
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week native_country
# count   48842.000000  48842.000000    48842.000000          47985
# unique           NaN           NaN             NaN             41
# top              NaN           NaN             NaN  United-States
# freq             NaN           NaN             NaN          43832
# mean     1079.067626     87.502314       40.422382            NaN
# std      7452.019058    403.004552       12.391444            NaN
# min         0.000000      0.000000        1.000000            NaN
# 25%         0.000000      0.000000       40.000000            NaN
# 50%         0.000000      0.000000       40.000000            NaN
# 75%         0.000000      0.000000       45.000000            NaN
# max     99999.000000   4356.000000       99.000000            NaN

# %%
adult.fillna(method='pad',inplace=True)
adult.fillna(method='bfill',inplace=True)

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# dtype: int64

# %%
adult.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country
# 0          2174             0              40  United-States
# 1             0             0              13  United-States
# 2             0             0              40  United-States
# 3             0             0              40  United-States
# 4             0             0              40           Cuba

# %%
adult.drop(['education','fnlwgt'],axis=1,inplace=True)

# %%
def data_transform(df):
    """Normalize features."""
    binary_data = pd.get_dummies(df,drop_first=True)
    feature_cols = binary_data[binary_data.columns]
    scaler = StandardScaler()
    data = pd.DataFrame(scaler.fit_transform(feature_cols), columns=feature_cols.columns)
    return data

# %%
adult = data_transform(adult)

# %%
adult.head()
# Out:
#         age  education_num  capital_gain  capital_loss  hours_per_week  \
# 0  0.025996       1.136512      0.146932     -0.217127       -0.034087
# 1  0.828308       1.136512     -0.144804     -0.217127       -2.213032
# 2 -0.046942      -0.419335     -0.144804     -0.217127       -0.034087
# 3  1.047121      -1.197259     -0.144804     -0.217127       -0.034087
# 4 -0.776316       1.136512     -0.144804     -0.217127       -0.034087
#
#    workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 0            -0.269229                -0.01431          -1.676343
# 1            -0.269229                -0.01431          -1.676343
# 2            -0.269229                -0.01431           0.596537
# 3            -0.269229                -0.01431           0.596537
# 4            -0.269229                -0.01431           0.596537
#
#    workclass_Self-emp-inc  workclass_Self-emp-not-inc  ...  \
# 0               -0.195216                   -0.302070  ...
# 1               -0.195216                    3.310491  ...
# 2               -0.195216                   -0.302070  ...
# 3               -0.195216                   -0.302070  ...
# 4               -0.195216                   -0.302070  ...
#
#    native_country_Portugal  native_country_Puerto-Rico  \
# 0                -0.037063                   -0.062161
# 1                -0.037063                   -0.062161
# 2                -0.037063                   -0.062161
# 3                -0.037063                   -0.062161
# 4                -0.037063                   -0.062161
#
#    native_country_Scotland  native_country_South  native_country_Taiwan  \
# 0                 -0.02074             -0.048581              -0.036505
# 1                 -0.02074             -0.048581              -0.036505
# 2                 -0.02074             -0.048581              -0.036505
# 3                 -0.02074             -0.048581              -0.036505
# 4                 -0.02074             -0.048581              -0.036505
#
#    native_country_Thailand  native_country_Trinadad&Tobago  \
# 0                -0.024791                       -0.023518
# 1                -0.024791                       -0.023518
# 2                -0.024791                       -0.023518
# 3                -0.024791                       -0.023518
# 4                -0.024791                       -0.023518
#
#    native_country_United-States  native_country_Vietnam  \
# 0                      0.307964               -0.043204
# 1                      0.307964               -0.043204
# 2                      0.307964               -0.043204
# 3                      0.307964               -0.043204
# 4                     -3.247128               -0.043204
#
#    native_country_Yugoslavia
# 0                   -0.02263
# 1                   -0.02263
# 2                   -0.02263
# 3                   -0.02263
# 4                   -0.02263
#
# [5 rows x 81 columns]

# %%
adult.shape
# Out:
# (48842, 81)

# %%
train_set=adult[:32561]

# %%
train_set.shape
# Out:
# (32561, 81)

# %%
test_set=adult[32561:]

# %%
test_set.shape
# Out:
# (16281, 81)

# %%
x_train=train_set
y_train=ad_target[:32561]

# %%
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: wage_class, Length: 32561, dtype: int64

# %%
from xgboost import XGBClassifier
model = XGBClassifier(objective='binary:logistic')
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
#training accuracy
y_train_pred=model.predict(x_train)
accuracy=accuracy_score(y_train,y_train_pred)
accuracy
# Out:
# 0.8656368047664383

# %%
x_test=test_set
y_test=ad_target[32561:]

# %%
x_test.head()
# Out:
#             age  education_num  capital_gain  capital_loss  hours_per_week  \
# 32561 -0.995129      -1.197259     -0.144804     -0.217127       -0.034087
# 32562 -0.046942      -0.419335     -0.144804     -0.217127        0.772930
# 32563 -0.776316       0.747550     -0.144804     -0.217127       -0.034087
# 32564  0.390683      -0.030373      0.886874     -0.217127       -0.034087
# 32565 -1.505691      -0.030373     -0.144804     -0.217127       -0.841104
#
#        workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# 32561            -0.269229                -0.01431           0.596537
# 32562            -0.269229                -0.01431           0.596537
# 32563             3.714313                -0.01431          -1.676343
# 32564            -0.269229                -0.01431           0.596537
# 32565            -0.269229                -0.01431           0.596537
#
#        workclass_Self-emp-inc  workclass_Self-emp-not-inc  ...  \
# 32561               -0.195216                    -0.30207  ...
# 32562               -0.195216                    -0.30207  ...
# 32563               -0.195216                    -0.30207  ...
# 32564               -0.195216                    -0.30207  ...
# 32565               -0.195216                    -0.30207  ...
#
#        native_country_Portugal  native_country_Puerto-Rico  \
# 32561                -0.037063                   -0.062161
# 32562                -0.037063                   -0.062161
# 32563                -0.037063                   -0.062161
# 32564                -0.037063                   -0.062161
# 32565                -0.037063                   -0.062161
#
#        native_country_Scotland  native_country_South  native_country_Taiwan  \
# 32561                 -0.02074             -0.048581              -0.036505
# 32562                 -0.02074             -0.048581              -0.036505
# 32563                 -0.02074             -0.048581              -0.036505
# 32564                 -0.02074             -0.048581              -0.036505
# 32565                 -0.02074             -0.048581              -0.036505
#
#        native_country_Thailand  native_country_Trinadad&Tobago  \
# 32561                -0.024791                       -0.023518
# 32562                -0.024791                       -0.023518
# 32563                -0.024791                       -0.023518
# 32564                -0.024791                       -0.023518
# 32565                -0.024791                       -0.023518
#
#        native_country_United-States  native_country_Vietnam  \
# 32561                      0.307964               -0.043204
# 32562                      0.307964               -0.043204
# 32563                      0.307964               -0.043204
# 32564                      0.307964               -0.043204
# 32565                      0.307964               -0.043204
#
#        native_country_Yugoslavia
# 32561                   -0.02263
# 32562                   -0.02263
# 32563                   -0.02263
# 32564                   -0.02263
# 32565                   -0.02263
#
# [5 rows x 81 columns]

# %%
#test accuracy
y_test_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_test_pred)
accuracy
# Out:
# 0.8670229101406548

# %%
param_grid={
   
    ' learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5,10,20],
    'n_estimators':[10,50,100,200]
    
}

# %%
from sklearn.model_selection import GridSearchCV
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid, verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# C:\Users\rt\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.839, total=   1.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.845, total=   1.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.848, total=   1.4s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.854, total=   5.6s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.857, total=   5.4s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.860, total=   5.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.859, total=  10.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.863, total=  10.9s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.869, total=  10.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.866, total=  21.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.869, total=  20.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.874, total=  20.6s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.850, total=   2.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.853, total=   1.9s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.858, total=   1.9s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.861, total=   8.7s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.864, total=   8.7s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.868, total=   8.6s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.867, total=  16.4s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.871, total=  16.4s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.874, total=  16.3s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.870, total=  33.4s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.872, total=  32.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.876, total=  32.0s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.857, total=   3.7s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.860, total=   3.9s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.865, total=   3.7s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.864, total=  17.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.868, total=  17.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.872, total=  16.9s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.867, total=  32.2s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.872, total=  32.6s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.872, total=  22.3s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.869, total=  35.0s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators

# [CV]   learning_rate=0.01, max_depth=20, n_estimators=10, score=0.863, total=   4.2s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=50, score=0.863, total=  20.8s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=50, score=0.865, total=  20.8s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=50, score=0.868, total=  20.7s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=100, score=0.864, total=  40.2s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=100, score=0.863, total=  39.6s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=100, score=0.870, total=  39.4s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=200, score=0.860, total= 1.3min
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=200, score=0.859, total= 1.3min
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=200, score=0.864, total= 1.3min
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=10, score=0.839, total=   0.9s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=10, score=0.845, total=   0.8s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=10, score=0.848, total=   0.9s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=50, score=0.854, total=   3.1s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=50, score=0.857, total=   3.3s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=50, score=0.860, total=   3.2s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=100, score=0.859, total=   6.1s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=100, score=0.863, total=   6.3s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=100, score=0.869, total=   6.2s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=200, score=0.866, total=  11.6s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=200, score=0.869, total=  12.3s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=200, score=0.874, total=  12.6s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=10, score=0.850, total=   1.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=10, score=0.853, total=   1.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=10, score=0.858, total=   1.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=50, score=0.861, total=   4.4s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=50, score=0.864, total=   4.5s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=50, score=0.868, total=   4.8s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=100, score=0.867, total=   9.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=100, score=0.871, total=   9.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=100, score=0.874, total=   9.5s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.870, total=  17.7s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.872, total=  18.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.876, total=  18.2s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.857, total=   2.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.860, total=   2.3s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.865, total=   2.2s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.864, total=   9.5s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.868, total=   9.8s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.872, total=   9.5s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.867, total=  18.0s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.872, total=  18.2s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.872, total=  17.7s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.869, total=  35.7s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.869, total=  31.9s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.871, total=  27.7s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.860, total=   3.2s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.859, total=   3.2s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.863, total=   3.3s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.863, total=  16.5s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.865, total=  16.7s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.868, total=  16.6s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.864, total=  31.5s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.863, total=  31.4s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.870, total=  31.0s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.860, total= 1.0min
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.859, total= 1.0min
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.864, total= 1.0min
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 70.3min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={' learning_rate': [1, 0.5, 0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 10, 20],
#                          'n_estimators': [10, 50, 100, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# To  find the parameters givingmaximum accuracy
grid.best_params_
# Out:
# {' learning_rate': 1, 'max_depth': 5, 'n_estimators': 200}

# %%
est=grid.best_estimator_

# %%
est
# Out:
# XGBClassifier( learning_rate=1, base_score=0.5, booster='gbtree',
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=200, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
est.score(x_test,y_test)
# Out:
# 0.8729807751366624

# %%
import pickle

# %%
filename = 'xg_model.pickle'
import pickle

pickle.dump(est, open(filename, 'wb'))

loaded_model = pickle.load(open(filename, 'rb'))
